# %%
import numpy as np

# %%
left_base = np.array([1.2143, 1.1178, 0.309])
right_base = np.array([0.6145, 1.1178, 0.309])
base_plate_width = 0.9135
object_origin = np.array([0.2464, 0.7993, 1.25])
object_delta_x = np.array([0.1489, 0.0, 0.0])
object_delta_y = np.array([0.0, 0.3771, 0.0])
rig_dimensions = np.array([1.82880035, 1.92391944, 1.971856])

# %%
i, j = 9, 2
object_pos = object_origin + i * object_delta_x + j * object_delta_y
print(object_pos.tolist())
# Out:
# [1.5865, 1.5535, 1.25]

# %%
mid_rig_pos = rig_dimensions / 2
print(mid_rig_pos)
# Out:
# [0.91440018 0.96195972 0.985928  ]
