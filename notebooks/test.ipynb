# %%
def check(e):
    print(f"{type(e).__name__}: {e}")
    if not isinstance(e, ValueError):
        return False
    if not str(e) == "a":
        return False
    return True

try:
    try:
        for 

except ExceptionGroup:
