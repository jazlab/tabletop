# %%
"""Imports."""

import numpy as np
from matplotlib import pyplot as plt

# %%
without_object = np.array(
    [
        [
            -1.6096026042938232,
            -1.9136961102485657,
            0.23926548302173614,
            -0.2246914412498474,
            0.056438024567067625,
            -0.09253790417909623,
        ],
        [
            -1.6067161133766175,
            -1.9091815271377564,
            0.17098254408836364,
            -0.21109724625349044,
            0.06105330648869276,
            -0.08648461080789566,
        ],
        [
            -1.6057295577049255,
            -1.949750400543213,
            0.22649457547664642,
            -0.2100779084444046,
            0.06694933045059442,
            -0.017382721573859453,
        ],
        [
            -1.6081801123142243,
            -1.9052370080947876,
            0.17236447682976722,
            -0.20428833209872246,
            0.06675266200006008,
            -0.02446755564138293,
        ],
        [
            -1.604939788389206,
            -1.9514063055038453,
            0.14950634142160416,
            -0.2287548244357109,
            0.0560579063847661,
            0.04605128950625658,
        ],
    ]
)
with_object = np.array(
    [
        [
            -1.6839293476104735,
            -2.007548685646057,
            0.1993397219181061,
            -0.24540851662755012,
            0.10593914423286915,
            0.06324057153761387,
        ],
        [
            -1.6522874448776246,
            -1.9042064356803894,
            0.24124646622538568,
            -0.22357711182832718,
            0.10745333448946476,
            0.058301987820863724,
        ],
        [
            -1.661545388174057,
            -1.8744297944545747,
            0.2171933362722397,
            -0.24201682106256486,
            0.103351143078506,
            0.036068467494845394,
        ],
        [
            -1.675290105009079,
            -1.8790352570056916,
            0.23371126858592034,
            -0.22379555976986884,
            0.09143018003702164,
            0.03850967875570059,
        ],
        [
            -1.6693411560058593,
            -1.9177154861927033,
            0.18267113744020463,
            -0.22730525187849998,
            0.1150271935224533,
            0.06865985763967038,
        ],
    ]
)
joints = [
    "elbow_joint",
    "shoulder_lift_joint",
    "shoulder_pan_joint",
    "wrist_1_joint",
    "wrist_2_joint",
    "wrist_3_joint",
]

# %%
fig, axes = plt.subplots(1, 6, figsize=(18, 3))
for i, ax in enumerate(axes):
    to_plot = np.stack([with_object[:, i], without_object[:, i]], axis=1)
    # ax.hist(without_object[:, i], color="r")
    # ax.hist(with_object[:, i], color="b")
    ax.hist(to_plot)
    ax.set_title(f"Joint {joints[i]}")
