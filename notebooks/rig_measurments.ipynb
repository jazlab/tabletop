# %%
import numpy as np

# %%
right_base = np.array([1.2468, 1.0832, 0.2685])
left_base = np.array([0.6583, 1.0832, 0.2685])
object_origin = np.array([0.2809, 0.7632, 1.2104])
object_delta = np.array([0.1489, 0.314, 0.628])
rig_dimensions = np.array([1.8669, 1.8923, 1.9812])
rig_mid = (rig_dimensions / 2).round(4)
base_plate_width = 0.9135
robot_base_radius = 0.075
print(f"rig_mid: {rig_mid}")
# Out:
# rig_mid: [0.9334 0.9462 0.9906]

# %%
lx, ly, lz = left_base
rx, ry, rz = right_base
sx, sy, sz = rig_dimensions
mx, my, mz = rig_mid
ox, oy, oz = object_origin

# %%
lx - 0.4 + 0.1
# Out:
# 0.35829999999999995

# %%
my - 0.3 + 0.5
# Out:
# 1.1462

# %%
# Out:
# 0.9815

# %%
i, j = 9, 2
object_pos = object_origin + i * object_delta_x + j * object_delta_y
print(object_pos.tolist())
# Out:
# [1.5865, 1.5535, 1.25]
